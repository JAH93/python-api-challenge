# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import the API key.
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
# Print (url)



city_data = []

print("Beginning Data Retrieval")
print ("-" * 15)



record_count = 1
set_count = 1

for index, city in enumerate(cities):
    
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 0

    city_url = url + "&q=" + city

    
    # Log the URL and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        
        
        city_weather = requests.get(city_url).json()
        
        
        # Extract out max temp humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the city info into the city data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })
    except:
        print("City not found. Skipping ...")
        pass
    # Indicate that data loading is complete
        print("-----------------------")
        print("Data Retrieval Complete")
        print("-----------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | constitucion
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | taoudenni
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | nogales
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | karamea
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 12 of Set 1 | te anau
# Processing Record 13 of Set 1 | sabha
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | idlib
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | hasaki
# Processing Record 22 of Set 1 | iquitos
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | buala
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | roebourne
# Processing Record 30 of Set 1 | zyryanovskiy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 1 | nsukka
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | tingrela
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | grao mogol
# Processing Record 39 of Set 1 | kanakapura
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | rungata
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | fairbanks
# Processing Record 45 of Set 1 | alyangula
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 47 of Set 1 | zhumadian
# Processing Record 48 of Set 1 | maulvi bazar
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 49 of Set 1 | inyonga
# Processing Record 50 of Set 1 | mehamn
# Processing Record 0 of Set 2 | busselton
# Processing Record 1 of Set 2 | bereznehuvate
# Processing Record 2 of Set 2 | barcelos
# Processing Record 3 of Set 2 | channel-port aux basques
# Processing Record 4 of Set 2 | taltal
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 2 | nantucket
# Processing Record 9 of Set 2 | labuhan
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | abu dhabi
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | seoul
# Processing Record 18 of Set 2 | kalemie
# Processing Record 19 of Set 2 | hualmay
# Processing Record 20 of Set 2 | ishigaki
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | perbaungan
# Processing Record 25 of Set 2 | chany
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | portland
# Processing Record 29 of Set 2 | saint-pierre
# Processing Record 30 of Set 2 | jalingo
# Processing Record 31 of Set 2 | saucillo
# Processing Record 32 of Set 2 | sao felix do xingu
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 2 | buritis
# Processing Record 36 of Set 2 | muros
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | henties bay
# Processing Record 39 of Set 2 | twin falls
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | rock hill
# Processing Record 42 of Set 2 | shingu
# Processing Record 43 of Set 2 | hit
# Processing Record 44 of Set 2 | yerbogachen
# Processing Record 45 of Set 2 | yomitan
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 46 of Set 2 | halden
# Processing Record 47 of Set 2 | moose factory
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | harper
# Processing Record 0 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 3 | dasoguz
# Processing Record 2 of Set 3 | phalodi
# Processing Record 3 of Set 3 | port hardy
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | mocuba
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 7 of Set 3 | aflu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 3 | falam
# Processing Record 9 of Set 3 | axim
# Processing Record 10 of Set 3 | sumter
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | barawe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 14 of Set 3 | mocambique
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 3 | qaqortoq
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | marathon
# Processing Record 20 of Set 3 | inhambane
# Processing Record 21 of Set 3 | tsaratanana
# Processing Record 22 of Set 3 | cairns
# Processing Record 23 of Set 3 | mecca
# Processing Record 24 of Set 3 | ushtobe
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 3 | hirara
# Processing Record 28 of Set 3 | doha
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | slave lake
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | bairiki
# Processing Record 33 of Set 3 | tinskoy
# Processing Record 34 of Set 3 | iberia
# Processing Record 35 of Set 3 | tshikapa
# Processing Record 36 of Set 3 | san quintin
# Processing Record 37 of Set 3 | smithers
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | faya
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 3 | lac du bonnet
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | plastun
# Processing Record 44 of Set 3 | saint-francois
# Processing Record 45 of Set 3 | yar-sale
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | dombarovskiy
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 0 of Set 4 | narsaq
# Processing Record 1 of Set 4 | bay roberts
# Processing Record 2 of Set 4 | naze
# Processing Record 3 of Set 4 | vao
# Processing Record 4 of Set 4 | cheney
# Processing Record 5 of Set 4 | dingle
# Processing Record 6 of Set 4 | podgornoye
# Processing Record 7 of Set 4 | maragogi
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | horsham
# Processing Record 10 of Set 4 | marawi
# Processing Record 11 of Set 4 | pontianak
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | khotiv
# Processing Record 14 of Set 4 | mindelo
# Processing Record 15 of Set 4 | kulhudhuffushi
# Processing Record 16 of Set 4 | taiobeiras
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | erenhot
# Processing Record 19 of Set 4 | zachagansk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 4 | isla mujeres
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | samalaeulu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 24 of Set 4 | ler
# Processing Record 25 of Set 4 | namatanai
# Processing Record 26 of Set 4 | marcona
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | abu zabad
# Processing Record 29 of Set 4 | nelson bay
# Processing Record 30 of Set 4 | upata
# Processing Record 31 of Set 4 | kalispell
# Processing Record 32 of Set 4 | gorele
# Processing Record 33 of Set 4 | ozubulu
# Processing Record 34 of Set 4 | bardiyah
# Processing Record 35 of Set 4 | kassala
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | sindhnur
# Processing Record 38 of Set 4 | yerofey pavlovich
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | bonoua
# Processing Record 41 of Set 4 | sola
# Processing Record 42 of Set 4 | coquimbo
# Processing Record 43 of Set 4 | lishan
# Processing Record 44 of Set 4 | ponta do sol
# Processing Record 45 of Set 4 | las vegas
# Processing Record 46 of Set 4 | sao jose da coroa grande
# Processing Record 47 of Set 4 | rocha
# Processing Record 48 of Set 4 | monrovia
# Processing Record 49 of Set 4 | umm kaddadah
# Processing Record 0 of Set 5 | sur
# Processing Record 1 of Set 5 | shubarshi
# Processing Record 2 of Set 5 | octeville
# Processing Record 3 of Set 5 | kidal
# Processing Record 4 of Set 5 | sinnamary
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | fengzhen
# Processing Record 7 of Set 5 | ancud
# Processing Record 8 of Set 5 | bima
# Processing Record 9 of Set 5 | poum
# Processing Record 10 of Set 5 | kahului
# Processing Record 11 of Set 5 | micheweni
# Processing Record 12 of Set 5 | waingapu
# Processing Record 13 of Set 5 | miyako
# Processing Record 14 of Set 5 | mendahara
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 5 | halifax
# Processing Record 16 of Set 5 | saint-leu
# Processing Record 17 of Set 5 | san blas
# Processing Record 18 of Set 5 | sangar
# Processing Record 19 of Set 5 | puro
# Processing Record 20 of Set 5 | teahupoo
# Processing Record 21 of Set 5 | wrexham
# Processing Record 22 of Set 5 | entre rios
# Processing Record 23 of Set 5 | vilhena
# Processing Record 24 of Set 5 | san lorenzo
# Processing Record 25 of Set 5 | canberra
# Processing Record 26 of Set 5 | vardo
# Processing Record 27 of Set 5 | kashi
# Processing Record 28 of Set 5 | cururupu
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | dryden
# Processing Record 31 of Set 5 | vestmannaeyjar
# Processing Record 32 of Set 5 | poyarkovo
# Processing Record 33 of Set 5 | qaanaaq
# Processing Record 34 of Set 5 | tawkar
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 5 | nizhneyansk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 5 | adrar
# Processing Record 37 of Set 5 | dwarka
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | biak
# Processing Record 41 of Set 5 | udachnyy
# Processing Record 42 of Set 5 | takoradi
# Processing Record 43 of Set 5 | ahipara
# Processing Record 44 of Set 5 | benjamin constant
# Processing Record 45 of Set 5 | tessalit
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | trinidad
# Processing Record 48 of Set 5 | porto seguro
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 0 of Set 6 | lagoa
# Processing Record 1 of Set 6 | aswan
# Processing Record 2 of Set 6 | sibolga
# Processing Record 3 of Set 6 | athabasca
# Processing Record 4 of Set 6 | lat yao
# Processing Record 5 of Set 6 | tarbagatay
# Processing Record 6 of Set 6 | nyimba
# Processing Record 7 of Set 6 | ketchikan
# Processing Record 8 of Set 6 | kirovskaya
# Processing Record 9 of Set 6 | burica
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 10 of Set 6 | kruisfontein
# Processing Record 11 of Set 6 | bethel
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | turkmenabat
# Processing Record 14 of Set 6 | lata
# Processing Record 15 of Set 6 | hun
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | ankazobe
# Processing Record 18 of Set 6 | pisco
# Processing Record 19 of Set 6 | koumac
# Processing Record 20 of Set 6 | chuy
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | bhinmal
# Processing Record 23 of Set 6 | sawtell
# Processing Record 24 of Set 6 | kyzyl-suu
# Processing Record 25 of Set 6 | ixtapa
# Processing Record 26 of Set 6 | codrington
# Processing Record 27 of Set 6 | vaitape
# Processing Record 28 of Set 6 | alekseyevsk
# Processing Record 29 of Set 6 | san joaquin
# Processing Record 30 of Set 6 | leh
# Processing Record 31 of Set 6 | maltahohe
# Processing Record 32 of Set 6 | la rioja
# Processing Record 33 of Set 6 | dandong
# Processing Record 34 of Set 6 | rockland
# Processing Record 35 of Set 6 | chokurdakh
# Processing Record 36 of Set 6 | shache
# Processing Record 37 of Set 6 | hobyo
# Processing Record 38 of Set 6 | mahebourg
# Processing Record 39 of Set 6 | isiro
# Processing Record 40 of Set 6 | waddan
# Processing Record 41 of Set 6 | kupang
# Processing Record 42 of Set 6 | tabuk
# Processing Record 43 of Set 6 | annamalainagar
# Processing Record 44 of Set 6 | limon
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | brownsville
# Processing Record 47 of Set 6 | warri
# Processing Record 48 of Set 6 | vanimo
# Processing Record 49 of Set 6 | khorixas
# Processing Record 0 of Set 7 | cheyenne
# Processing Record 1 of Set 7 | la union
# Processing Record 2 of Set 7 | nouakchott
# Processing Record 3 of Set 7 | touros
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | mys shmidta
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 6 of Set 7 | bara
# Processing Record 7 of Set 7 | turan
# Processing Record 8 of Set 7 | poronaysk
# Processing Record 9 of Set 7 | diego de almagro
# Processing Record 10 of Set 7 | dikson
# Processing Record 11 of Set 7 | biloela
# Processing Record 12 of Set 7 | middelkerke
# Processing Record 13 of Set 7 | moba
# Processing Record 14 of Set 7 | oistins
# Processing Record 15 of Set 7 | angelholm
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 16 of Set 7 | salalah
# Processing Record 17 of Set 7 | saint george
# Processing Record 18 of Set 7 | sungairaya
# Processing Record 19 of Set 7 | yanam
# Processing Record 20 of Set 7 | myitkyina
# Processing Record 21 of Set 7 | brae
# Processing Record 22 of Set 7 | churachandpur
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | narasannapeta
# Processing Record 25 of Set 7 | fram
# Processing Record 26 of Set 7 | seminole
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | richards bay
# Processing Record 29 of Set 7 | yangliuqing
# Processing Record 30 of Set 7 | kalivai poliyirou
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 7 | ust-tsilma
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | sicuani
# Processing Record 34 of Set 7 | highland village
# Processing Record 35 of Set 7 | biskamzha
# Processing Record 36 of Set 7 | bull savanna
# Processing Record 37 of Set 7 | nara
# Processing Record 38 of Set 7 | lompoc
# Processing Record 39 of Set 7 | calabozo
# Processing Record 40 of Set 7 | mount pleasant
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | jega
# Processing Record 43 of Set 7 | nykobing
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 44 of Set 7 | kosonsoy
# Processing Record 45 of Set 7 | manati
# Processing Record 46 of Set 7 | poya
# Processing Record 47 of Set 7 | tommot
# Processing Record 48 of Set 7 | san andres
# Processing Record 49 of Set 7 | manjacaze
# Processing Record 0 of Set 8 | mongo
# Processing Record 1 of Set 8 | alpena
# Processing Record 2 of Set 8 | sirnak
# Processing Record 3 of Set 8 | chegutu
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | yaan
# Processing Record 6 of Set 8 | praia da vitoria
# Processing Record 7 of Set 8 | moron
# Processing Record 8 of Set 8 | mergui
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | tautira
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 13 of Set 8 | mladenovac
# Processing Record 14 of Set 8 | kaitangata
# Processing Record 15 of Set 8 | tazovskiy
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | toyohashi
# Processing Record 18 of Set 8 | gazanjyk
# Processing Record 19 of Set 8 | borogontsy
# Processing Record 20 of Set 8 | warrington
# Processing Record 21 of Set 8 | muyezerskiy
# Processing Record 22 of Set 8 | gigmoto
# Processing Record 23 of Set 8 | okandja
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 24 of Set 8 | rozkishne
# Processing Record 25 of Set 8 | bonfim
# Processing Record 26 of Set 8 | provideniya
# Processing Record 27 of Set 8 | altay
# Processing Record 28 of Set 8 | santiago del estero
# Processing Record 29 of Set 8 | voorst
# Processing Record 30 of Set 8 | vung tau
# Processing Record 31 of Set 8 | bramming
# Processing Record 32 of Set 8 | swan hill
# Processing Record 33 of Set 8 | todos santos
# Processing Record 34 of Set 8 | bambous virieux
# Processing Record 35 of Set 8 | onega
# Processing Record 36 of Set 8 | clyde river
# Processing Record 37 of Set 8 | ust-kuyga
# Processing Record 38 of Set 8 | joaquim nabuco
# Processing Record 39 of Set 8 | rio grande city
# Processing Record 40 of Set 8 | karratha
# Processing Record 41 of Set 8 | rio gallegos
# Processing Record 42 of Set 8 | powell river
# Processing Record 43 of Set 8 | redlands
# Processing Record 44 of Set 8 | bathsheba
# Processing Record 45 of Set 8 | midland
# Processing Record 46 of Set 8 | mount isa
# Processing Record 47 of Set 8 | baft
# Processing Record 48 of Set 8 | flin flon
# Processing Record 49 of Set 8 | nazare
# Processing Record 0 of Set 9 | rognan
# Processing Record 1 of Set 9 | havre-saint-pierre
# Processing Record 2 of Set 9 | alice springs
# Processing Record 3 of Set 9 | jinchengjiang
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 4 of Set 9 | grand river south east
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 9 | samusu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 6 of Set 9 | tolaga bay
# Processing Record 7 of Set 9 | rottingdean
# Processing Record 8 of Set 9 | daru
# Processing Record 9 of Set 9 | kedarnath
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 10 of Set 9 | tual
# Processing Record 11 of Set 9 | guerrero negro
# Processing Record 12 of Set 9 | khandyga
# Processing Record 13 of Set 9 | batagay-alyta
# Processing Record 14 of Set 9 | smolenka
# Processing Record 15 of Set 9 | reconquista
# Processing Record 16 of Set 9 | luanda
# Processing Record 17 of Set 9 | jalu
# Processing Record 18 of Set 9 | lorengau
# Processing Record 19 of Set 9 | korla
# Processing Record 20 of Set 9 | awjilah
# Processing Record 21 of Set 9 | quatre cocos
# Processing Record 22 of Set 9 | chicama
# Processing Record 23 of Set 9 | pringsewu
# Processing Record 24 of Set 9 | krasnoselkup
# Processing Record 25 of Set 9 | louisbourg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 26 of Set 9 | semnan
# Processing Record 27 of Set 9 | paragominas
# Processing Record 28 of Set 9 | marsh harbour
# Processing Record 29 of Set 9 | puerto del rosario
# Processing Record 30 of Set 9 | houlung
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 9 | santa fe
# Processing Record 32 of Set 9 | carmen
# Processing Record 33 of Set 9 | iqaluit
# Processing Record 34 of Set 9 | port hedland
# Processing Record 35 of Set 9 | olafsvik
# Processing Record 36 of Set 9 | bodden town
# Processing Record 37 of Set 9 | lazaro cardenas
# Processing Record 38 of Set 9 | doctor pedro p. pena
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 9 | los llanos de aridane
# Processing Record 40 of Set 9 | xining
# Processing Record 41 of Set 9 | okhotsk
# Processing Record 42 of Set 9 | lasa
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | lons
# Processing Record 45 of Set 9 | ostrovnoy
# Processing Record 46 of Set 9 | nanzhang
# Processing Record 47 of Set 9 | hambantota
# Processing Record 48 of Set 9 | santa cruz
# Processing Record 49 of Set 9 | sataua
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 0 of Set 10 | ust-shonosha
# Processing Record 1 of Set 10 | hamilton
# Processing Record 2 of Set 10 | sorland
# Processing Record 3 of Set 10 | ekhabi
# Processing Record 4 of Set 10 | poso
# Processing Record 5 of Set 10 | pichayevo
# Processing Record 6 of Set 10 | kavieng
# Processing Record 7 of Set 10 | daur
# Processing Record 8 of Set 10 | saint-joseph
# Processing Record 9 of Set 10 | angoche
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | raudeberg
# Processing Record 12 of Set 10 | teguldet
# Processing Record 13 of Set 10 | corowa
# Processing Record 14 of Set 10 | launceston
# Processing Record 15 of Set 10 | komsomolskiy
# Processing Record 16 of Set 10 | isla vista
# Processing Record 17 of Set 10 | kloulklubed
# Processing Record 18 of Set 10 | oktyabrskiy
# Processing Record 19 of Set 10 | houma
# Processing Record 20 of Set 10 | portree
# Processing Record 21 of Set 10 | kapit
# Processing Record 22 of Set 10 | walvis bay
# Processing Record 23 of Set 10 | nusaybin
# Processing Record 24 of Set 10 | jieshi
# Processing Record 25 of Set 10 | ucluelet
# Processing Record 26 of Set 10 | cap-aux-meules
# Processing Record 27 of Set 10 | berlevag
# Processing Record 28 of Set 10 | madimba
# Processing Record 29 of Set 10 | metro
# Processing Record 30 of Set 10 | pacific grove
# Processing Record 31 of Set 10 | isla del bosque
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | jacareacanga
# Processing Record 34 of Set 10 | oktyabrskoye
# Processing Record 35 of Set 10 | lar gerd
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 10 | turayf
# Processing Record 37 of Set 10 | valleyview
# Processing Record 38 of Set 10 | sandwick
# Processing Record 39 of Set 10 | beringovskiy
# Processing Record 40 of Set 10 | manggar
# Processing Record 41 of Set 10 | kpandu
# Processing Record 42 of Set 10 | dubrovnik
# Processing Record 43 of Set 10 | bilma
# Processing Record 44 of Set 10 | bud
# Processing Record 45 of Set 10 | port-cartier
# Processing Record 46 of Set 10 | westport
# Processing Record 47 of Set 10 | huayang
# Processing Record 48 of Set 10 | impfondo
# Processing Record 49 of Set 10 | aksu
# Processing Record 0 of Set 11 | soyo
# Processing Record 1 of Set 11 | roura
# Processing Record 2 of Set 11 | sheridan
# Processing Record 3 of Set 11 | tocopilla
# Processing Record 4 of Set 11 | srednekolymsk
# Processing Record 5 of Set 11 | tezu
# Processing Record 6 of Set 11 | davila
# Processing Record 7 of Set 11 | nguiu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 11 | bolshegrivskoye
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 9 of Set 11 | bandarbeyla
# Processing Record 10 of Set 11 | vryburg
# Processing Record 11 of Set 11 | grindavik
# Processing Record 12 of Set 11 | nemuro
# Processing Record 13 of Set 11 | marsa matruh
# Processing Record 14 of Set 11 | mayor pablo lagerenza
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | tilichiki
# Processing Record 17 of Set 11 | alexandria
# Processing Record 18 of Set 11 | burnie
# Processing Record 19 of Set 11 | assiniboia
# Processing Record 20 of Set 11 | port macquarie
# Processing Record 21 of Set 11 | lucapa
# Processing Record 22 of Set 11 | killybegs
# Processing Record 23 of Set 11 | nautla
# Processing Record 24 of Set 11 | shenjiamen
# Processing Record 25 of Set 11 | wasilla
# Processing Record 26 of Set 11 | gilbues
# Processing Record 27 of Set 11 | kamaishi
# Processing Record 28 of Set 11 | makung
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 11 | sao miguel do araguaia
# Processing Record 30 of Set 11 | porto murtinho
# Processing Record 31 of Set 11 | mutis
# Processing Record 32 of Set 11 | sembakung
# Processing Record 33 of Set 11 | dicabisagan
# Processing Record 34 of Set 11 | tiksi
# Processing Record 35 of Set 11 | dosso
# Processing Record 36 of Set 11 | usinsk
# Processing Record 37 of Set 11 | bahia honda
# Processing Record 38 of Set 11 | tabiauea
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 11 | sabang
# Processing Record 40 of Set 11 | floro
# Processing Record 41 of Set 11 | bourail
# Processing Record 42 of Set 11 | yarmouth
# Processing Record 43 of Set 11 | cuajinicuilapa
# Processing Record 44 of Set 11 | niamey
# Processing Record 45 of Set 11 | latina
# Processing Record 46 of Set 11 | shelbyville
# Processing Record 47 of Set 11 | soledade
# Processing Record 48 of Set 11 | pak phanang
# Processing Record 49 of Set 11 | mogwase
# Processing Record 0 of Set 12 | yanchukan
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | koslan
# Processing Record 3 of Set 12 | laguna
# Processing Record 4 of Set 12 | fort saint john
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 12 | da nang
# Processing Record 6 of Set 12 | bolshoy tsaryn
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 7 of Set 12 | kurchum
# Processing Record 8 of Set 12 | tashara
# Processing Record 9 of Set 12 | keti bandar
# Processing Record 10 of Set 12 | ouadda
# Processing Record 11 of Set 12 | karla
# Processing Record 12 of Set 12 | itacoatiara
# Processing Record 13 of Set 12 | sarkand
# Processing Record 14 of Set 12 | gazojak
# Processing Record 15 of Set 12 | akyab
# Processing Record 16 of Set 12 | alta floresta
# Processing Record 17 of Set 12 | xingyi
# Processing Record 18 of Set 12 | tuni
# Processing Record 19 of Set 12 | hoquiam
# Processing Record 20 of Set 12 | haifa
# Processing Record 21 of Set 12 | leningradskiy
# Processing Record 22 of Set 12 | verkhnetulomskiy
# Processing Record 23 of Set 12 | alofi
# Processing Record 24 of Set 12 | rio blanco
# Processing Record 25 of Set 12 | kichmengskiy gorodok
# Processing Record 26 of Set 12 | yenagoa
# Processing Record 27 of Set 12 | aksarka
# Processing Record 28 of Set 12 | gjusvik
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 12 | bella union
# Processing Record 30 of Set 12 | verkhoyansk
# Processing Record 31 of Set 12 | mrirt
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 32 of Set 12 | pedernales
# Processing Record 33 of Set 12 | neepawa
# Processing Record 34 of Set 12 | winnemucca
# Processing Record 35 of Set 12 | namibe
# Processing Record 36 of Set 12 | payo
# Processing Record 37 of Set 12 | ambatofinandrahana
# Processing Record 38 of Set 12 | voh
# Processing Record 39 of Set 12 | saint-georges
# Processing Record 40 of Set 12 | mormugao
# Processing Record 41 of Set 12 | bulawayo
# Processing Record 42 of Set 12 | ananas
# Processing Record 43 of Set 12 | baykit
# Processing Record 44 of Set 12 | mangai
# Processing Record 45 of Set 12 | luderitz
# Processing Record 46 of Set 12 | gold coast
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | alekseyevka
# Processing Record 49 of Set 12 | sept-iles
# Processing Record 0 of Set 13 | gagnoa
# Processing Record 1 of Set 13 | zhanaozen
# Processing Record 2 of Set 13 | san
# Processing Record 3 of Set 13 | balykshi
# Processing Record 4 of Set 13 | vestmanna
# Processing Record 5 of Set 13 | talara
# Processing Record 6 of Set 13 | nur
# Processing Record 7 of Set 13 | necochea
# Processing Record 8 of Set 13 | porbandar
# Processing Record 9 of Set 13 | nago

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSON into Pandas
city_data_df = pd.DataFrame(city_data)


# Extract relevant fields from the data frame
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Windspeed"]

city_data_df.to_csv(index_label="City_ID")

city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Windspeed     558
# Country       558
# Date          558
# dtype: int64

# %%
# Display the city Data Frame
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  Windspeed  \
# 0  constitucion -35.3333  -72.4167     51.13        85          75      11.34
# 1       mataura -46.1927  168.8643     46.47        58         100       1.90
# 2    vila velha -20.3297  -40.2925     71.55        91          40       5.75
# 3     taoudenni  22.6783   -3.9836     98.40        26          11      14.16
# 4      saldanha -33.0117   17.9442     56.97        86         100      21.79
#
#   Country        Date
# 0      CL  1661383956
# 1      NZ  1661383957
# 2      BR  1661383374
# 3      ML  1661383958
# 4      ZA  1661383327

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats,
            max_temps,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs. Humidity
plt.scatter(lats,
            humidity,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build scatter plot for latitude vs. Cloudiness
plt.scatter(lats,
            cloudiness,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. Windspeed
plt.scatter(lats,
            wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Windspeed mph")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
plt.savefig("Fig4.png")

# Show plot

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.6688714039696179

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.7489002148027666

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: -0.09832650581256358

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.06048685876651588

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.02463203003554487

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.032141309961045514

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (40,25))
# Out:
# The r-squared is: 0.091112199425869

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (-30,30))
# Out:
# The r-squared is: -0.14411675818790554
